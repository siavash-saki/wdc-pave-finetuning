# %% [markdown]
# # 06 — Fine-Tuning (Variant D)
#
# LoRA/QLoRA fine-tuning of an open-source model. Likely runs on Colab or SageMaker.
#
# **Covers:**
# - Prepare SFT dataset (instruction + product text → target JSON)
# - Configure LoRA/QLoRA hyperparameters
# - Train on the train split, monitor loss on validation split
# - Save adapter checkpoints to `outputs/models/`
# - Run inference with fine-tuned model on val split
# - Save predictions to `data/WDC-PAVE/predictions/` in standardized format
# - Log GPU hours, wall-clock time, throughput
#
# **Next steps after this notebook:**
# - Notebook 07: proprietary API baseline (Variant E)
# - Notebook 08: full evaluation across all variants (A–E)
# - Notebook 09: results comparison and visualization
