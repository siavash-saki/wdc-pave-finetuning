# %% [markdown]
# # 09 — Results Comparison & Visualization
#
# Final summary tables and charts across all experiment variants.
#
# **Covers:**
# - Aggregate result table (all variants x all metrics)
# - Per-category Field F1 breakdown table
# - Visualizations: bar charts comparing variants, category heatmaps
# - Trade-off analysis: quality vs latency vs cost
# - Error analysis summary: common failure patterns per variant
# - Key findings and recommendations
